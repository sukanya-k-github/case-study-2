# %% [markdown]
# # STUDENTS PERFORMANCES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:\\Users\\MY\\Downloads\\StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # 1. Males And Females

# %%
df.gender.value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %% [markdown]
# # 2.Parental Level Of Education

# %%
df['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
sns.displot(df['parental level of education'])

# %% [markdown]
# # 3. Best Performance(based on Gender)

# %%
df1=df.drop(df.columns[[1,2,3,4]],axis=1)
df1
# Out:
#      gender  math score  reading score  writing score
# 0    female           0             17             10
# 1    female           8             24             23
# 2    female          18             32             28
# 3    female          11             38             32
# 4    female          22             39             33
# ..      ...         ...            ...            ...
# 995    male          99             87             81
# 996    male         100             96             86
# 997    male         100             97             99
# 998    male         100            100             93
# 999    male         100            100            100
#
# [1000 rows x 4 columns]

# %%
df1['avg_score']=df1.mean(axis=1)
df1
# Out:
#      gender  math score  reading score  writing score   avg_score
# 0    female           0             17             10    9.000000
# 1    female           8             24             23   18.333333
# 2    female          18             32             28   26.000000
# 3    female          11             38             32   27.000000
# 4    female          22             39             33   31.333333
# ..      ...         ...            ...            ...         ...
# 995    male          99             87             81   89.000000
# 996    male         100             96             86   94.000000
# 997    male         100             97             99   98.666667
# 998    male         100            100             93   97.666667
# 999    male         100            100            100  100.000000
#
# [1000 rows x 5 columns]

# %%
df1.nlargest(3,columns='avg_score')
# Out:
#      gender  math score  reading score  writing score  avg_score
# 516  female         100            100            100      100.0
# 517  female         100            100            100      100.0
# 999    male         100            100            100      100.0

# %% [markdown]
# # Best Performance(based on Test Preparation Course)

# %%
df2=df.drop(df.columns[[0,1,2,3]],axis=1)
df2
# Out:
#     test preparation course  math score  reading score  writing score
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
# [1000 rows x 4 columns]

# %%
df2['avg_score']=df2.mean(axis=1)
df2
# Out:
#     test preparation course  math score  reading score  writing score  \
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
#       avg_score
# 0      9.000000
# 1     18.333333
# 2     26.000000
# 3     27.000000
# 4     31.333333
# ..          ...
# ...

# %%
df2.nlargest(3,columns='avg_score')
# Out:
#     test preparation course  math score  reading score  writing score  \
# 516                    none         100            100            100
# 517                    none         100            100            100
# 999               completed         100            100            100
#
#      avg_score
# 516      100.0
# 517      100.0
# 999      100.0

# %% [markdown]
# # 4.Scoring Variations ( based on gender and test preparation course )

# %%
df1
# Out:
#      gender  math score  reading score  writing score   avg_score
# 0    female           0             17             10    9.000000
# 1    female           8             24             23   18.333333
# 2    female          18             32             28   26.000000
# 3    female          11             38             32   27.000000
# 4    female          22             39             33   31.333333
# ..      ...         ...            ...            ...         ...
# 995    male          99             87             81   89.000000
# 996    male         100             96             86   94.000000
# 997    male         100             97             99   98.666667
# 998    male         100            100             93   97.666667
# 999    male         100            100            100  100.000000
#
# [1000 rows x 5 columns]

# %%
female=df1[df1.gender=='female']
female
# Out:
#      gender  math score  reading score  writing score   avg_score
# 0    female           0             17             10    9.000000
# 1    female           8             24             23   18.333333
# 2    female          18             32             28   26.000000
# 3    female          11             38             32   27.000000
# 4    female          22             39             33   31.333333
# ..      ...         ...            ...            ...         ...
# 513  female          99            100            100   99.666667
# 514  female          99             93             90   94.000000
# 515  female         100             92             97   96.333333
# 516  female         100            100            100  100.000000
# 517  female         100            100            100  100.000000
#
# [518 rows x 5 columns]

# %%
female.mean()
# Out:
# math score       63.376448
# reading score    72.590734
# writing score    72.467181
# avg_score        69.478121
# dtype: float64

# %%
male=df1[df1.gender=='male']
male
# Out:
#     gender  math score  reading score  writing score   avg_score
# 518   male          27             34             36   32.333333
# 519   male          28             23             19   23.333333
# 520   male          30             24             15   23.000000
# 521   male          30             26             22   26.000000
# 522   male          31             32             34   32.333333
# ..     ...         ...            ...            ...         ...
# 995   male          99             87             81   89.000000
# 996   male         100             96             86   94.000000
# 997   male         100             97             99   98.666667
# 998   male         100            100             93   97.666667
# 999   male         100            100            100  100.000000
#
# [482 rows x 5 columns]

# %%
male.mean()
# Out:
# math score       68.821577
# reading score    65.545643
# writing score    63.446058
# avg_score        65.937759
# dtype: float64

# %%
df2
# Out:
#     test preparation course  math score  reading score  writing score  \
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
#       avg_score
# 0      9.000000
# 1     18.333333
# 2     26.000000
# 3     27.000000
# 4     31.333333
# ..          ...
# ...

# %%
completed=df2[df2['test preparation course']=='completed']
completed
# Out:
#     test preparation course  math score  reading score  writing score  \
# 5                 completed          23             44             36
# 10                completed          29             40             44
# 12                completed          32             51             44
# 16                completed          34             48             41
# 21                completed          35             55             60
# ..                      ...         ...            ...            ...
# 995               completed          99             87             81
# 996               completed         100             96             86
# 997               completed         100             97             99
# 998               completed         100            100             93
# 999               completed         100            100            100
#
#       avg_score
# 5     34.333333
# 10    37.666667
# 12    42.333333
# 16    41.000000
# 21    50.000000
# ..          ...
# ...

# %%
completed.mean()
# Out:
# math score       69.966480
# reading score    74.175978
# writing score    74.684358
# avg_score        72.942272
# dtype: float64

# %%
none=df2[df2['test preparation course']=='none']
none
# Out:
#     test preparation course  math score  reading score  writing score  \
# 0                      none           0             17             10
# 1                      none           8             24             23
# 2                      none          18             32             28
# 3                      none          11             38             32
# 4                      none          22             39             33
# ..                      ...         ...            ...            ...
# 984                    none          94             88             78
# 986                    none          94             73             71
# 987                    none          95             81             84
# 990                    none          97             93             91
# 991                    none          97             87             82
#
#      avg_score
# 0     9.000000
# 1    18.333333
# 2    26.000000
# 3    27.000000
# 4    31.333333
# ..         ...
# ...

# %%
none.mean()
# Out:
# math score       63.789720
# reading score    66.417445
# writing score    64.457944
# avg_score        64.888370
# dtype: float64

# %% [markdown]
# # 5. Bonus Points

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("C:\\Users\\MY\\Downloads\\StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.nlargest(250,columns='math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 515  female        group E                some college      standard
# 516  female        group E           bachelor's degree      standard
# 517  female        group E          associate's degree      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# ..      ...            ...                         ...           ...
# 428  female        group D                some college  free/reduced
# 429  female        group E            some high school      standard
# 849    male        group A           bachelor's degree      standard
# 850    male        group C          associate's degree  free/reduced
# 851    male        group D                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...
